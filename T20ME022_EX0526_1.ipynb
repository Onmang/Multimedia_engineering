# %% [markdown]
# <a href="https://colab.research.google.com/github/Onmang/Multimedia_engineering/blob/master/T20ME022_EX0526_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 # opencv
import matplotlib.pyplot as plt # 画像を描画させるライブラリ
import numpy as np

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/fujisan.jpg') 
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # BGR系からRGB系に変換

# %%
plt.imshow(img)

# %%
grayimg = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY) 
plt.imshow(grayimg, cmap='gray')

# %%
# 2値化
binimg = (grayimg > 180) * 255
plt.imshow(binimg, cmap='gray')

# %%
# シャープ化
filter = np.array([[ -1,  -1,  -1],
                   [ -1,   9,  -1],
                   [ -1,  -1,  -1]], np.float32)
filtered = cv2.filter2D(grayimg, -1, filter)
plt.imshow(filtered, cmap='gray')

# %%
# ぼかし
filter = np.array([[ 1/9,  1/9,  1/9],
                   [ 1/9,   1/9,  1/9],
                   [ 1/9,  1/9,  1/9]], np.float32)
filtered = cv2.filter2D(grayimg, -1, filter)
plt.imshow(filtered, cmap='gray')

# %%
# エッジ

# 横方向
filter = np.array([[ -1, 0, 1],
                   [ -1, 0, 1],
                   [ -1, 0, 1]], np.float32)
# 縦方向
filter2 = np.array([[ -1, -1, -1],
                   [ 0, 0, 0],
                   [ 1, 1, 1]], np.float32)
filtered = cv2.filter2D(grayimg, -1, filter)
filtered2 = cv2.filter2D(grayimg, -1, filter2)

filtered3 = filtered + filtered2
plt.imshow(filtered, cmap='gray')
plt.show()
plt.imshow(filtered2, cmap='gray')
plt.show()
# 縦横組み合わせ
plt.imshow(filtered3, cmap='gray')
plt.show()
